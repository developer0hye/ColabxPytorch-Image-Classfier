# %% [markdown]
# <a href="https://colab.research.google.com/github/developer0hye/ColabXPytorch-Image-Classfier/blob/master/training_classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip /content/drive/"My Drive"/dataset/Kuroko_X_Kagami.zip -d /content/drive/"My Drive"/dataset/
# Out:
# Archive:  /content/drive/My Drive/dataset/Kuroko_X_Kagami.zip
# replace /content/drive/My Drive/dataset/Kuroko_X_Kagami/test/kagami/kagami_30.PNG? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/test/kagami/kagami_30.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/test/kagami/kagami_31.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/test/kagami/kagami_32.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/test/kagami/kagami_33.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/test/kagami/kagami_34.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/test/kagami/kagami_35.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/test/kagami/kagami_36.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/test/kagami/kagami_37.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/test/kagami/kagami_38.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/test/kagami/kagami_39.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/test/kuroko/kuroko_30.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/test/kuroko/kuroko_31.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/test/kuroko/kuroko_32.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/test/kuroko/kuroko_33.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/test/kuroko/kuroko_34.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/test/kuroko/kuroko_35.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/test/kuroko/kuroko_36.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/test/kuroko/kuroko_37.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/test/kuroko/kuroko_38.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/test/kuroko/kuroko_39.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kagami/kagami_1.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kagami/kagami_10.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kagami/kagami_11.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kagami/kagami_12.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kagami/kagami_13.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kagami/kagami_14.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kagami/kagami_15.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kagami/kagami_16.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kagami/kagami_17.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kagami/kagami_18.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kagami/kagami_19.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kagami/kagami_2.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kagami/kagami_20.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kagami/kagami_21.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kagami/kagami_22.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kagami/kagami_23.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kagami/kagami_24.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kagami/kagami_25.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kagami/kagami_26.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kagami/kagami_27.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kagami/kagami_28.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kagami/kagami_29.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kagami/kagami_3.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kagami/kagami_4.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kagami/kagami_40.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kagami/kagami_41.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kagami/kagami_42.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kagami/kagami_43.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kagami/kagami_44.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kagami/kagami_45.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kagami/kagami_46.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kagami/kagami_47.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kagami/kagami_48.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kagami/kagami_49.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kagami/kagami_5.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kagami/kagami_50.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kagami/kagami_51.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kagami/kagami_52.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kagami/kagami_53.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kagami/kagami_54.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kagami/kagami_55.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kagami/kagami_56.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kagami/kagami_57.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kagami/kagami_58.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kagami/kagami_59.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kagami/kagami_6.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kagami/kagami_60.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kagami/kagami_7.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kagami/kagami_8.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kagami/kagami_9.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kuroko/kuroko_1.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kuroko/kuroko_10.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kuroko/kuroko_11.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kuroko/kuroko_12.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kuroko/kuroko_13.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kuroko/kuroko_14.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kuroko/kuroko_15.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kuroko/kuroko_16.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kuroko/kuroko_17.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kuroko/kuroko_18.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kuroko/kuroko_19.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kuroko/kuroko_2.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kuroko/kuroko_20.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kuroko/kuroko_21.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kuroko/kuroko_22.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kuroko/kuroko_23.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kuroko/kuroko_24.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kuroko/kuroko_25.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kuroko/kuroko_26.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kuroko/kuroko_27.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kuroko/kuroko_28.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kuroko/kuroko_29.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kuroko/kuroko_3.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kuroko/kuroko_4.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kuroko/kuroko_40.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kuroko/kuroko_41.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kuroko/kuroko_42.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kuroko/kuroko_43.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kuroko/kuroko_44.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kuroko/kuroko_45.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kuroko/kuroko_46.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kuroko/kuroko_47.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kuroko/kuroko_48.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kuroko/kuroko_49.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kuroko/kuroko_5.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kuroko/kuroko_50.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kuroko/kuroko_51.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kuroko/kuroko_52.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kuroko/kuroko_53.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kuroko/kuroko_54.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kuroko/kuroko_55.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kuroko/kuroko_56.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kuroko/kuroko_57.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kuroko/kuroko_58.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kuroko/kuroko_59.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kuroko/kuroko_6.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kuroko/kuroko_60.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kuroko/kuroko_7.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kuroko/kuroko_8.PNG
#   inflating: /content/drive/My Drive/dataset/Kuroko_X_Kagami/train/kuroko/kuroko_9.PNG

# %% [markdown]
# # Model

# %%
from torch import nn

class SuperLightMobileNet(nn.Module):
    def __init__(self, num_classes=1000):
        super(SuperLightMobileNet, self).__init__()

        def conv_bn(inp, oup, stride):
            return nn.Sequential(
                nn.Conv2d(inp, oup, 3, stride, 1, bias=False),
                nn.BatchNorm2d(oup),
                nn.ReLU(inplace=True)
            )

        def conv_dw(inp, oup, stride):
            return nn.Sequential(
                nn.Conv2d(inp, inp, 3, stride, 1, groups=inp, bias=False),
                nn.BatchNorm2d(inp),
                nn.ReLU(inplace=True),
    
                nn.Conv2d(inp, oup, 1, 1, 0, bias=False),
                nn.BatchNorm2d(oup),
                nn.ReLU(inplace=True),
            )
        self.num_classes = num_classes
        self.model = nn.Sequential(
            conv_bn(  3,  16, 2), 
            conv_dw( 16,  32, 1),
            conv_dw( 32, 64, 2),
            conv_dw(64, 64, 1),
            conv_dw(64, 128, 2),
            conv_dw(128, 128, 1),
            conv_dw(128, 256, 2),
            conv_dw(256, 256, 1),
            conv_dw(256, 512, 2),
            conv_dw(512, 512, 1),
            conv_dw(512, 1024, 1)
        )
        self.gap = nn.AdaptiveAvgPool2d((1, 1))
        self.fc = nn.Linear(1024, self.num_classes)

    def forward(self, x):
        x = self.model(x)
        x = self.gap(x)
        x = x.view(-1, 1024)
        x = self.fc(x)
        return x

# %% [markdown]
# # Hyperprameters & Device Setting

# %%
import torch

#hyp parameters
dataset_path = "/content/drive/My Drive/dataset/Kuroko_X_Kagami"
model_weight_save_path = "/content/drive/My Drive/model/"
num_classes = 2

batch_size = 16
num_workers = 8
lr = 1e-3

total_epoch = 30

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Dataset & Dataloader Setting

# %%
import torch
from torch.utils.data import DataLoader
from torch import nn
from torchvision import transforms
import torchvision.datasets as datasets
import os


# Data loading code
traindir = os.path.join(dataset_path, 'train')
testdir = os.path.join(dataset_path, 'test')

# normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
#                                   std=[0.229, 0.224, 0.225])

train_dataset = datasets.ImageFolder(
    traindir,
    transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        #normalize,
    ]))

train_loader = torch.utils.data.DataLoader(
    train_dataset, batch_size=batch_size, shuffle=True,
    num_workers=num_workers, pin_memory=True, drop_last=False)

test_loader = torch.utils.data.DataLoader(
    datasets.ImageFolder(testdir, transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        #normalize,
    ])),
    batch_size=batch_size, shuffle=False,
    num_workers=num_workers, pin_memory=True)

# %% [markdown]
# # Model Initialization

# %%
model = SuperLightMobileNet(num_classes).to(device)

# %% [markdown]
# # Loss & Optimizer

# %%
CEloss = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# %% [markdown]
# # Training & Evaluation

# %%
import numpy as np

total_iteration_per_epoch = int(np.ceil(len(train_dataset)/batch_size))

for epoch in range(1, total_epoch + 1):
    model.train()
    for itereation, (input, target) in enumerate(train_loader):
        images = input.to(device)
        labels = target.to(device)

        # Forward pass
        outputs = model(images)
        loss = CEloss(outputs, labels)

        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        print('Epoch [{}/{}], Iteration [{}/{}] Loss: {:.4f}'.format(epoch, total_epoch, itereation+1, total_iteration_per_epoch, loss.item()))
    if epoch % 10 == 0:
      torch.save(model.state_dict(), model_weight_save_path + 'model_' + str(epoch) + ".pth")
    
    model.eval()
    with torch.no_grad():
      correct = 0
      total = 0
      for input, target in test_loader:
          images = input.to(device)
          labels = target.to(device)

          # Forward pass
          outputs = model(images)
          _, predicted = torch.max(outputs.data, 1)
          total += len(labels)
          correct += (predicted == labels).sum().item()

      print('Epoch [{}/{}], Test Accuracy of the model on the {} test images: {} %'.format(epoch, total_epoch, total, 100 * correct / total))
# Out:
# Epoch [35/50], Iteration [1/7] Loss: 0.0011
# Epoch [35/50], Iteration [2/7] Loss: 0.0065
# Epoch [35/50], Iteration [3/7] Loss: 0.0031
# Epoch [35/50], Iteration [4/7] Loss: 0.0003
# Epoch [35/50], Iteration [5/7] Loss: 0.1244
# Epoch [35/50], Iteration [6/7] Loss: 0.0468
# Epoch [35/50], Iteration [7/7] Loss: 0.0215
# Epoch [35/50], Test Accuracy of the model on the 20 test images: 100.0 %
# Epoch [36/50], Iteration [1/7] Loss: 0.0007
# Epoch [36/50], Iteration [2/7] Loss: 0.0052
# Epoch [36/50], Iteration [3/7] Loss: 0.0175
# Epoch [36/50], Iteration [4/7] Loss: 0.0043
# Epoch [36/50], Iteration [5/7] Loss: 0.0000
# Epoch [36/50], Iteration [6/7] Loss: 0.0003
# Epoch [36/50], Iteration [7/7] Loss: 0.0095
# Epoch [36/50], Test Accuracy of the model on the 20 test images: 100.0 %
# Epoch [37/50], Iteration [1/7] Loss: 0.0000
# Epoch [37/50], Iteration [2/7] Loss: 0.0068
# Epoch [37/50], Iteration [3/7] Loss: 0.0001
# Epoch [37/50], Iteration [4/7] Loss: 0.0003
# Epoch [37/50], Iteration [5/7] Loss: 0.0004
# Epoch [37/50], Iteration [6/7] Loss: 0.0016
# Epoch [37/50], Iteration [7/7] Loss: 0.0000
# Epoch [37/50], Test Accuracy of the model on the 20 test images: 100.0 %
# Epoch [38/50], Iteration [1/7] Loss: 0.0001
# Epoch [38/50], Iteration [2/7] Loss: 0.0769
# Epoch [38/50], Iteration [3/7] Loss: 0.0004
# Epoch [38/50], Iteration [4/7] Loss: 0.0002
# Epoch [38/50], Iteration [5/7] Loss: 0.0003
# Epoch [38/50], Iteration [6/7] Loss: 0.0061
# Epoch [38/50], Iteration [7/7] Loss: 3.3061
# Epoch [38/50], Test Accuracy of the model on the 20 test images: 100.0 %
# Epoch [39/50], Iteration [1/7] Loss: 0.0010
# Epoch [39/50], Iteration [2/7] Loss: 0.1947
# Epoch [39/50], Iteration [3/7] Loss: 0.0139
# Epoch [39/50], Iteration [4/7] Loss: 1.7111
# Epoch [39/50], Iteration [5/7] Loss: 0.2538
# Epoch [39/50], Iteration [6/7] Loss: 0.0014
# Epoch [39/50], Iteration [7/7] Loss: 0.0397
# Epoch [39/50], Test Accuracy of the model on the 20 test images: 100.0 %
# Epoch [40/50], Iteration [1/7] Loss: 0.0034
# Epoch [40/50], Iteration [2/7] Loss: 0.0131
# Epoch [40/50], Iteration [3/7] Loss: 0.0433
# Epoch [40/50], Iteration [4/7] Loss: 0.2527
# Epoch [40/50], Iteration [5/7] Loss: 0.0011
# Epoch [40/50], Iteration [6/7] Loss: 0.0136
# Epoch [40/50], Iteration [7/7] Loss: 0.0168
# Epoch [40/50], Test Accuracy of the model on the 20 test images: 100.0 %
# Epoch [41/50], Iteration [1/7] Loss: 0.6537
# Epoch [41/50], Iteration [2/7] Loss: 0.0034
# Epoch [41/50], Iteration [3/7] Loss: 0.0328
# Epoch [41/50], Iteration [4/7] Loss: 0.0113
# Epoch [41/50], Iteration [5/7] Loss: 0.0322
# Epoch [41/50], Iteration [6/7] Loss: 0.0116
# Epoch [41/50], Iteration [7/7] Loss: 0.0354
# Epoch [41/50], Test Accuracy of the model on the 20 test images: 100.0 %
# Epoch [42/50], Iteration [1/7] Loss: 0.0963
# Epoch [42/50], Iteration [2/7] Loss: 0.0163
# Epoch [42/50], Iteration [3/7] Loss: 0.0074
# Epoch [42/50], Iteration [4/7] Loss: 0.1071
# Epoch [42/50], Iteration [5/7] Loss: 0.0427
# Epoch [42/50], Iteration [6/7] Loss: 0.0098
# Epoch [42/50], Iteration [7/7] Loss: 0.0055
# Epoch [42/50], Test Accuracy of the model on the 20 test images: 100.0 %
# Epoch [43/50], Iteration [1/7] Loss: 0.0170
# Epoch [43/50], Iteration [2/7] Loss: 0.0164
# Epoch [43/50], Iteration [3/7] Loss: 0.0064
# Epoch [43/50], Iteration [4/7] Loss: 0.0413
# Epoch [43/50], Iteration [5/7] Loss: 0.0040
# Epoch [43/50], Iteration [6/7] Loss: 0.2637
# Epoch [43/50], Iteration [7/7] Loss: 0.0061
# Epoch [43/50], Test Accuracy of the model on the 20 test images: 100.0 %
# Epoch [44/50], Iteration [1/7] Loss: 0.0093
# Epoch [44/50], Iteration [2/7] Loss: 0.0045
# Epoch [44/50], Iteration [3/7] Loss: 0.0081
# Epoch [44/50], Iteration [4/7] Loss: 0.8878
# Epoch [44/50], Iteration [5/7] Loss: 0.0140
# Epoch [44/50], Iteration [6/7] Loss: 0.0592
# Epoch [44/50], Iteration [7/7] Loss: 0.0298
# Epoch [44/50], Test Accuracy of the model on the 20 test images: 100.0 %
# Epoch [45/50], Iteration [1/7] Loss: 0.0110
# Epoch [45/50], Iteration [2/7] Loss: 0.0192
# Epoch [45/50], Iteration [3/7] Loss: 0.0204
# Epoch [45/50], Iteration [4/7] Loss: 0.0080
# Epoch [45/50], Iteration [5/7] Loss: 0.0183
# Epoch [45/50], Iteration [6/7] Loss: 0.1685
# Epoch [45/50], Iteration [7/7] Loss: 0.0076
# Epoch [45/50], Test Accuracy of the model on the 20 test images: 100.0 %
# Epoch [46/50], Iteration [1/7] Loss: 0.3090
# Epoch [46/50], Iteration [2/7] Loss: 0.0345
# Epoch [46/50], Iteration [3/7] Loss: 0.0067
# Epoch [46/50], Iteration [4/7] Loss: 0.0253
# Epoch [46/50], Iteration [5/7] Loss: 0.0693
# Epoch [46/50], Iteration [6/7] Loss: 0.0148
# Epoch [46/50], Iteration [7/7] Loss: 0.0047
# Epoch [46/50], Test Accuracy of the model on the 20 test images: 100.0 %
# Epoch [47/50], Iteration [1/7] Loss: 0.0074
# Epoch [47/50], Iteration [2/7] Loss: 0.0232
# Epoch [47/50], Iteration [3/7] Loss: 0.2418
# Epoch [47/50], Iteration [4/7] Loss: 0.0112
# Epoch [47/50], Iteration [5/7] Loss: 0.0084
# Epoch [47/50], Iteration [6/7] Loss: 0.0171
# Epoch [47/50], Iteration [7/7] Loss: 0.0292
# Epoch [47/50], Test Accuracy of the model on the 20 test images: 100.0 %
# Epoch [48/50], Iteration [1/7] Loss: 0.0312
# Epoch [48/50], Iteration [2/7] Loss: 0.0164
# Epoch [48/50], Iteration [3/7] Loss: 0.1070
# Epoch [48/50], Iteration [4/7] Loss: 0.0098
# Epoch [48/50], Iteration [5/7] Loss: 0.0137
# Epoch [48/50], Iteration [6/7] Loss: 0.0049
# Epoch [48/50], Iteration [7/7] Loss: 0.0061
# Epoch [48/50], Test Accuracy of the model on the 20 test images: 100.0 %
# Epoch [49/50], Iteration [1/7] Loss: 0.0165
# Epoch [49/50], Iteration [2/7] Loss: 0.0075
# Epoch [49/50], Iteration [3/7] Loss: 0.0043
# Epoch [49/50], Iteration [4/7] Loss: 0.0053
# Epoch [49/50], Iteration [5/7] Loss: 0.0030
# Epoch [49/50], Iteration [6/7] Loss: 0.2463
# Epoch [49/50], Iteration [7/7] Loss: 0.0076
# Epoch [49/50], Test Accuracy of the model on the 20 test images: 100.0 %
# Epoch [50/50], Iteration [1/7] Loss: 0.0172
# Epoch [50/50], Iteration [2/7] Loss: 0.0040
# Epoch [50/50], Iteration [3/7] Loss: 0.0768
# Epoch [50/50], Iteration [4/7] Loss: 0.0164
# Epoch [50/50], Iteration [5/7] Loss: 0.0026
# Epoch [50/50], Iteration [6/7] Loss: 0.2153
# Epoch [50/50], Iteration [7/7] Loss: 0.0382
# Epoch [50/50], Test Accuracy of the model on the 20 test images: 100.0 %
# Epoch [1/30], Iteration [1/7] Loss: 0.6689
# Epoch [1/30], Iteration [2/7] Loss: 0.7246
# Epoch [1/30], Iteration [3/7] Loss: 0.6020
# Epoch [1/30], Iteration [4/7] Loss: 0.5772
# Epoch [1/30], Iteration [5/7] Loss: 0.4033
# Epoch [1/30], Iteration [6/7] Loss: 0.2598
# Epoch [1/30], Iteration [7/7] Loss: 0.1907
# Epoch [1/30], Test Accuracy of the model on the 20 test images: 50.0 %
# Epoch [2/30], Iteration [1/7] Loss: 0.1408
# Epoch [2/30], Iteration [2/7] Loss: 0.3836
# Epoch [2/30], Iteration [3/7] Loss: 0.7679
# Epoch [2/30], Iteration [4/7] Loss: 0.0946
# Epoch [2/30], Iteration [5/7] Loss: 0.0058
# Epoch [2/30], Iteration [6/7] Loss: 0.0198
# Epoch [2/30], Iteration [7/7] Loss: 0.0211
# Epoch [2/30], Test Accuracy of the model on the 20 test images: 50.0 %
# Epoch [3/30], Iteration [1/7] Loss: 0.6228
# Epoch [3/30], Iteration [2/7] Loss: 0.1523
# Epoch [3/30], Iteration [3/7] Loss: 0.0397
# Epoch [3/30], Iteration [4/7] Loss: 0.0090
# Epoch [3/30], Iteration [5/7] Loss: 0.6241
# Epoch [3/30], Iteration [6/7] Loss: 0.0998
# Epoch [3/30], Iteration [7/7] Loss: 0.0067
# Epoch [3/30], Test Accuracy of the model on the 20 test images: 50.0 %
# Epoch [4/30], Iteration [1/7] Loss: 0.3034
# Epoch [4/30], Iteration [2/7] Loss: 0.2360
# Epoch [4/30], Iteration [3/7] Loss: 0.1687
# Epoch [4/30], Iteration [4/7] Loss: 0.1739
# Epoch [4/30], Iteration [5/7] Loss: 0.5347
# Epoch [4/30], Iteration [6/7] Loss: 0.1850
# Epoch [4/30], Iteration [7/7] Loss: 0.0120
# Epoch [4/30], Test Accuracy of the model on the 20 test images: 50.0 %
# Epoch [5/30], Iteration [1/7] Loss: 0.0745
# Epoch [5/30], Iteration [2/7] Loss: 0.1262
# Epoch [5/30], Iteration [3/7] Loss: 0.2282
# Epoch [5/30], Iteration [4/7] Loss: 0.0050
# Epoch [5/30], Iteration [5/7] Loss: 0.0195
# Epoch [5/30], Iteration [6/7] Loss: 0.1589
# Epoch [5/30], Iteration [7/7] Loss: 1.9994
# Epoch [5/30], Test Accuracy of the model on the 20 test images: 50.0 %
# Epoch [6/30], Iteration [1/7] Loss: 0.1065
# Epoch [6/30], Iteration [2/7] Loss: 0.0933
# Epoch [6/30], Iteration [3/7] Loss: 0.1242
# Epoch [6/30], Iteration [4/7] Loss: 0.0231
# Epoch [6/30], Iteration [5/7] Loss: 0.7850
# Epoch [6/30], Iteration [6/7] Loss: 0.0613
# Epoch [6/30], Iteration [7/7] Loss: 0.0853
# Epoch [6/30], Test Accuracy of the model on the 20 test images: 55.0 %
# Epoch [7/30], Iteration [1/7] Loss: 0.0393
# Epoch [7/30], Iteration [2/7] Loss: 0.0175
# Epoch [7/30], Iteration [3/7] Loss: 0.0157
# Epoch [7/30], Iteration [4/7] Loss: 0.0187
# Epoch [7/30], Iteration [5/7] Loss: 0.0907
# Epoch [7/30], Iteration [6/7] Loss: 0.2544
# Epoch [7/30], Iteration [7/7] Loss: 0.0100
# Epoch [7/30], Test Accuracy of the model on the 20 test images: 90.0 %
# Epoch [8/30], Iteration [1/7] Loss: 0.0260
# Epoch [8/30], Iteration [2/7] Loss: 0.0287
# Epoch [8/30], Iteration [3/7] Loss: 0.0352
# Epoch [8/30], Iteration [4/7] Loss: 0.0171
# Epoch [8/30], Iteration [5/7] Loss: 0.3416
# Epoch [8/30], Iteration [6/7] Loss: 0.0286
# Epoch [8/30], Iteration [7/7] Loss: 0.0068
# Epoch [8/30], Test Accuracy of the model on the 20 test images: 85.0 %
# Epoch [9/30], Iteration [1/7] Loss: 0.0331
# Epoch [9/30], Iteration [2/7] Loss: 0.0952
# Epoch [9/30], Iteration [3/7] Loss: 0.0102
# Epoch [9/30], Iteration [4/7] Loss: 0.0140
# Epoch [9/30], Iteration [5/7] Loss: 0.0183
# Epoch [9/30], Iteration [6/7] Loss: 0.0371
# Epoch [9/30], Iteration [7/7] Loss: 0.1204
# Epoch [9/30], Test Accuracy of the model on the 20 test images: 95.0 %
# Epoch [10/30], Iteration [1/7] Loss: 0.0044
# Epoch [10/30], Iteration [2/7] Loss: 0.0112
# Epoch [10/30], Iteration [3/7] Loss: 0.0037
# Epoch [10/30], Iteration [4/7] Loss: 0.0417
# Epoch [10/30], Iteration [5/7] Loss: 0.0187
# Epoch [10/30], Iteration [6/7] Loss: 0.0095
# Epoch [10/30], Iteration [7/7] Loss: 0.0325
# Epoch [10/30], Test Accuracy of the model on the 20 test images: 100.0 %
# Epoch [11/30], Iteration [1/7] Loss: 0.0139
# Epoch [11/30], Iteration [2/7] Loss: 0.0252
# Epoch [11/30], Iteration [3/7] Loss: 0.1178
# Epoch [11/30], Iteration [4/7] Loss: 0.0058
# Epoch [11/30], Iteration [5/7] Loss: 0.0056
# Epoch [11/30], Iteration [6/7] Loss: 0.0043
# Epoch [11/30], Iteration [7/7] Loss: 2.7040
# Epoch [11/30], Test Accuracy of the model on the 20 test images: 100.0 %
# Epoch [12/30], Iteration [1/7] Loss: 0.0244
# Epoch [12/30], Iteration [2/7] Loss: 0.0755
# Epoch [12/30], Iteration [3/7] Loss: 0.0105
# Epoch [12/30], Iteration [4/7] Loss: 0.0085
# Epoch [12/30], Iteration [5/7] Loss: 0.0162
# Epoch [12/30], Iteration [6/7] Loss: 0.0519
# Epoch [12/30], Iteration [7/7] Loss: 0.0028
# Epoch [12/30], Test Accuracy of the model on the 20 test images: 65.0 %
# Epoch [13/30], Iteration [1/7] Loss: 0.0191
# Epoch [13/30], Iteration [2/7] Loss: 0.1004
# Epoch [13/30], Iteration [3/7] Loss: 0.0275
# Epoch [13/30], Iteration [4/7] Loss: 0.0269
# Epoch [13/30], Iteration [5/7] Loss: 0.0255
# Epoch [13/30], Iteration [6/7] Loss: 0.0390
# Epoch [13/30], Iteration [7/7] Loss: 0.1401
# Epoch [13/30], Test Accuracy of the model on the 20 test images: 100.0 %
# Epoch [14/30], Iteration [1/7] Loss: 0.0152
# Epoch [14/30], Iteration [2/7] Loss: 0.0325
# Epoch [14/30], Iteration [3/7] Loss: 0.0071
# Epoch [14/30], Iteration [4/7] Loss: 0.0310
# Epoch [14/30], Iteration [5/7] Loss: 0.0274
# Epoch [14/30], Iteration [6/7] Loss: 0.0382
# Epoch [14/30], Iteration [7/7] Loss: 0.0064
# Epoch [14/30], Test Accuracy of the model on the 20 test images: 100.0 %
# Epoch [15/30], Iteration [1/7] Loss: 0.0622
# Epoch [15/30], Iteration [2/7] Loss: 0.0059
# Epoch [15/30], Iteration [3/7] Loss: 0.0659
# Epoch [15/30], Iteration [4/7] Loss: 0.0201
# Epoch [15/30], Iteration [5/7] Loss: 0.0032
# Epoch [15/30], Iteration [6/7] Loss: 0.0729
# Epoch [15/30], Iteration [7/7] Loss: 0.0428
# Epoch [15/30], Test Accuracy of the model on the 20 test images: 100.0 %
# Epoch [16/30], Iteration [1/7] Loss: 0.1320
# Epoch [16/30], Iteration [2/7] Loss: 0.0184
# Epoch [16/30], Iteration [3/7] Loss: 0.1100
# Epoch [16/30], Iteration [4/7] Loss: 0.0012
# Epoch [16/30], Iteration [5/7] Loss: 0.3264
# Epoch [16/30], Iteration [6/7] Loss: 0.0298
# Epoch [16/30], Iteration [7/7] Loss: 0.0942
# Epoch [16/30], Test Accuracy of the model on the 20 test images: 100.0 %
# Epoch [17/30], Iteration [1/7] Loss: 0.0124
# Epoch [17/30], Iteration [2/7] Loss: 0.0017
# Epoch [17/30], Iteration [3/7] Loss: 0.1856
# Epoch [17/30], Iteration [4/7] Loss: 0.0078
# Epoch [17/30], Iteration [5/7] Loss: 0.0012
# Epoch [17/30], Iteration [6/7] Loss: 0.0010
# Epoch [17/30], Iteration [7/7] Loss: 0.0007
# Epoch [17/30], Test Accuracy of the model on the 20 test images: 100.0 %
# Epoch [18/30], Iteration [1/7] Loss: 0.0025
# Epoch [18/30], Iteration [2/7] Loss: 0.0314
# Epoch [18/30], Iteration [3/7] Loss: 0.0046
# Epoch [18/30], Iteration [4/7] Loss: 0.0016
# Epoch [18/30], Iteration [5/7] Loss: 0.0007
# Epoch [18/30], Iteration [6/7] Loss: 0.0027
# Epoch [18/30], Iteration [7/7] Loss: 1.2205
# Epoch [18/30], Test Accuracy of the model on the 20 test images: 100.0 %
# Epoch [19/30], Iteration [1/7] Loss: 0.0202
# Epoch [19/30], Iteration [2/7] Loss: 0.0016
# Epoch [19/30], Iteration [3/7] Loss: 0.0032
# Epoch [19/30], Iteration [4/7] Loss: 0.0066
# Epoch [19/30], Iteration [5/7] Loss: 0.0326
# Epoch [19/30], Iteration [6/7] Loss: 0.0358
# Epoch [19/30], Iteration [7/7] Loss: 0.0140
# Epoch [19/30], Test Accuracy of the model on the 20 test images: 80.0 %
# Epoch [20/30], Iteration [1/7] Loss: 0.2795
# Epoch [20/30], Iteration [2/7] Loss: 0.0401
# Epoch [20/30], Iteration [3/7] Loss: 0.4901
# Epoch [20/30], Iteration [4/7] Loss: 0.0308
# Epoch [20/30], Iteration [5/7] Loss: 0.0065
# Epoch [20/30], Iteration [6/7] Loss: 0.0064
# Epoch [20/30], Iteration [7/7] Loss: 0.4693
# Epoch [20/30], Test Accuracy of the model on the 20 test images: 100.0 %
# Epoch [21/30], Iteration [1/7] Loss: 0.0913
# Epoch [21/30], Iteration [2/7] Loss: 0.0118
# Epoch [21/30], Iteration [3/7] Loss: 0.0219
# Epoch [21/30], Iteration [4/7] Loss: 0.0096
# Epoch [21/30], Iteration [5/7] Loss: 0.0125
# Epoch [21/30], Iteration [6/7] Loss: 0.0048
# Epoch [21/30], Iteration [7/7] Loss: 0.0021
# Epoch [21/30], Test Accuracy of the model on the 20 test images: 100.0 %
# Epoch [22/30], Iteration [1/7] Loss: 0.2178
# Epoch [22/30], Iteration [2/7] Loss: 0.0115
# Epoch [22/30], Iteration [3/7] Loss: 0.0648
# Epoch [22/30], Iteration [4/7] Loss: 0.0089
# Epoch [22/30], Iteration [5/7] Loss: 0.0069
# Epoch [22/30], Iteration [6/7] Loss: 0.0049
# Epoch [22/30], Iteration [7/7] Loss: 0.1270
# Epoch [22/30], Test Accuracy of the model on the 20 test images: 100.0 %
# Epoch [23/30], Iteration [1/7] Loss: 0.0138
# Epoch [23/30], Iteration [2/7] Loss: 0.0060
# Epoch [23/30], Iteration [3/7] Loss: 0.0074
# Epoch [23/30], Iteration [4/7] Loss: 0.0141
# Epoch [23/30], Iteration [5/7] Loss: 0.0050
# Epoch [23/30], Iteration [6/7] Loss: 0.0057
# Epoch [23/30], Iteration [7/7] Loss: 0.0020
# Epoch [23/30], Test Accuracy of the model on the 20 test images: 100.0 %
# Epoch [24/30], Iteration [1/7] Loss: 0.0244
# Epoch [24/30], Iteration [2/7] Loss: 0.0698
# Epoch [24/30], Iteration [3/7] Loss: 0.0057
# Epoch [24/30], Iteration [4/7] Loss: 0.0290
# Epoch [24/30], Iteration [5/7] Loss: 0.0134
# Epoch [24/30], Iteration [6/7] Loss: 0.0137
# Epoch [24/30], Iteration [7/7] Loss: 0.0023
# Epoch [24/30], Test Accuracy of the model on the 20 test images: 100.0 %
# Epoch [25/30], Iteration [1/7] Loss: 0.0169
# Epoch [25/30], Iteration [2/7] Loss: 0.0055
# Epoch [25/30], Iteration [3/7] Loss: 0.1651
# Epoch [25/30], Iteration [4/7] Loss: 0.0047
# Epoch [25/30], Iteration [5/7] Loss: 0.0312
# Epoch [25/30], Iteration [6/7] Loss: 0.0183
# Epoch [25/30], Iteration [7/7] Loss: 0.0341
# Epoch [25/30], Test Accuracy of the model on the 20 test images: 100.0 %
# Epoch [26/30], Iteration [1/7] Loss: 0.0069
# Epoch [26/30], Iteration [2/7] Loss: 0.0024
# Epoch [26/30], Iteration [3/7] Loss: 0.0494
# Epoch [26/30], Iteration [4/7] Loss: 1.4746
# Epoch [26/30], Iteration [5/7] Loss: 0.0052
# Epoch [26/30], Iteration [6/7] Loss: 0.0028
# Epoch [26/30], Iteration [7/7] Loss: 0.7639
# Epoch [26/30], Test Accuracy of the model on the 20 test images: 100.0 %
# Epoch [27/30], Iteration [1/7] Loss: 0.0056
# Epoch [27/30], Iteration [2/7] Loss: 0.0035
# Epoch [27/30], Iteration [3/7] Loss: 0.0073
# Epoch [27/30], Iteration [4/7] Loss: 0.0090
# Epoch [27/30], Iteration [5/7] Loss: 0.0452
# Epoch [27/30], Iteration [6/7] Loss: 0.0596
# Epoch [27/30], Iteration [7/7] Loss: 0.0468
# Epoch [27/30], Test Accuracy of the model on the 20 test images: 80.0 %
# Epoch [28/30], Iteration [1/7] Loss: 0.0375
# Epoch [28/30], Iteration [2/7] Loss: 0.0243
# Epoch [28/30], Iteration [3/7] Loss: 0.0321
# Epoch [28/30], Iteration [4/7] Loss: 0.1624
# Epoch [28/30], Iteration [5/7] Loss: 0.1356
# Epoch [28/30], Iteration [6/7] Loss: 0.2638
# Epoch [28/30], Iteration [7/7] Loss: 0.0081
# Epoch [28/30], Test Accuracy of the model on the 20 test images: 85.0 %
# Epoch [29/30], Iteration [1/7] Loss: 0.0562
# Epoch [29/30], Iteration [2/7] Loss: 0.0213
# Epoch [29/30], Iteration [3/7] Loss: 0.6844
# Epoch [29/30], Iteration [4/7] Loss: 0.0082
# Epoch [29/30], Iteration [5/7] Loss: 0.0831
# Epoch [29/30], Iteration [6/7] Loss: 0.0140
# Epoch [29/30], Iteration [7/7] Loss: 0.0543
# Epoch [29/30], Test Accuracy of the model on the 20 test images: 100.0 %
# Epoch [30/30], Iteration [1/7] Loss: 0.0375
# Epoch [30/30], Iteration [2/7] Loss: 0.1819
# Epoch [30/30], Iteration [3/7] Loss: 0.0275
# Epoch [30/30], Iteration [4/7] Loss: 0.0303
# Epoch [30/30], Iteration [5/7] Loss: 0.0521
# Epoch [30/30], Iteration [6/7] Loss: 0.0494
# Epoch [30/30], Iteration [7/7] Loss: 0.5117
# Epoch [30/30], Test Accuracy of the model on the 20 test images: 100.0 %
